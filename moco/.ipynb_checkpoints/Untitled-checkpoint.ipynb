# %%
import torch.utils.data as data
from torchvision import transforms
from PIL import Image
import sys
sys.path.append('..')
# from config import INPUT_SIZE


class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list, transform=None):
        self.transform = transform
        self.data_root = data_root
       # print(self.data_root)
        f = open(self.data_root + data_list, 'r')
        data_list = f.readlines()
        f.close()

        self.n_data = len(data_list)

        self.img_paths = []
        self.labels = []

        for data in data_list:
            image_path = data[:-1]
            label = image_path.split('/')[1]
            self.img_paths.append(image_path)
            self.labels.append(label)

        print(len(set(self.labels)))

        self.label_dict = {}
        for i, label in enumerate(list(set(self.labels))):
            self.label_dict[label] = i

        print(self.label_dict)

    def __getitem__(self, item):

     #   print(self.data_root)
        img_path, label= self.img_paths[item], self.labels[item]
        #img_path_full = os.path.join(self.data_root, img_path)
        img_path_full = self.data_root+img_path
      #  print(img_path_full)
        img = Image.open(img_path_full).convert('RGB')
        # label = np.array(label,dtype='float32')
        label = self.label_dict[label]
        if self.transform is not None:
            img = self.transform(img)

        return img, label

    def __len__(self):
        return self.n_data

# %%
total_trainset = GetLoader(data_root='/userdata/smetzger/data/logos/train_and_test/train/',
        data_list='train_images_root.txt',
        transform=None)
# Out:
# 116958
# 2341

# %%
total_testset = GetLoader(data_root='/userdata/smetzger/data/logos/train_and_test/test/',
        data_list='test_images_root.txt',
        transform=None)
# Out:
# 50182
# 2341

# %%
total_testset.label_dict == total_trainset.label_dict
# Out:
# True

# %%
i, k  = total_testset[1500]

# %%
i
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F5E07A628D0>

# %%
new_train[k], new_test[k]
# Out:
# ('Don Jose', 'Don Jose')

# %%
new_test = {} 
for item, key in total_testset.label_dict.items(): 
    new_test[key] = item
    
new_train = {} 
for item, key in total_trainset.label_dict.items(): 
    new_train[key] = item

# %%
new_test
# Out:
# {0: 'Scholler',
#  1: 'Oreo',
#  2: 'Mist',
#  3: 'McCafe',
#  4: 'Frosted Toast Crunch',
#  5: 'KP Nuts',
#  6: "Smith's Crisps",
#  7: 'Nine West',
#  8: 'Butterfinger Bites',
#  9: 'Kix',
#  10: 'Top',
#  11: 'H. J. Heinz',
#  12: 'Akubra',
#  13: 'Marmara',
#  14: 'Standard',
#  15: 'Karma',
#  16: 'Tropicana',
#  17: 'Gateway',
#  18: 'La Vie',
#  19: "Reese's Puffs",
#  20: 'Calvin Klein',
#  21: 'PG Tips',
#  22: 'Cathay',
#  23: 'Vittel',
#  24: 'Amora',
#  25: 'Pertamina',
#  26: 'Texas Roadhouse',
#  27: 'Rima',
#  28: 'Kent',
#  29: 'Neutral',
#  30: 'saky',
#  31: 'Campbells',
#  32: 'J. Lancaster & Son',
#  33: 'The Real Deal',
#  34: 'DC Shoes',
#  35: 'Elf',
#  36: 'Buffalo Rock Ginger Ale',
#  37: 'Mr Greedy',
#  38: 'Senator',
#  39: 'Choice Hotels',
#  40: 'Breath Savers',
#  41: 'Domus',
#  42: 'Bassett',
#  43: 'Liga',
#  44: 'Julmust',
#  45: 'Vimto',
#  46: 'SUNING',
#  47: 'Molson Canadian 67',
#  48: 'Organic Wild Puffs',
#  49: 'Schweppes Tonic',
#  50: 'Kern',
#  51: "Newman's Own",
#  52: 'Life is good',
#  53: 'Supra',
#  54: 'Crown',
#  55: 'Persil',
#  56: 'Los Angeles',
#  57: 'Coco Pops',
#  58: 'Albertsons',
#  59: 'Leed',
#  60: 'SBR',
#  61: 'DMC',
#  62: 'Marble Slab Creamery',
#  63: 'Avanti',
#  64: 'Corn Flakes',
#  65: 'Bona',
#  66: 'Ameristar Jet Charter',
#  67: "Birki's",
#  68: 'Chiclets',
#  69: 'Aztec',
#  70: 'Cocio',
#  71: 'Aiptek',
#  72: 'MAD DOG',
#  73: 'Monster Moca',
#  74: 'Snapple',
#  75: 'Peerless',
#  76: 'kepeng',
#  77: 'Pure',
#  78: 'Gazelle',
#  79: 'MONDI',
#  80: "Shakey's Pizza",
#  81: 'Trio',
#  82: 'Lifan',
#  83: 'Mountain Equipment',
#  84: 'Thomson',
#  85: 'Colonial',
#  86: 'D-Link',
#  87: 'Jiaozhou',
#  88: 'La Aurora',
#  89: 'Swiss',
#  90: 'Axe',
#  91: 'Ellesse',
#  92: 'Toby',
#  93: 'Origins',
#  94: 'Charmin',
#  95: 'Breguet',
#  96: 'Acer',
#  97: 'ROSLE',
#  98: 'Landwind',
#  99: 'La Gloria Cubana',
#  100: 'Arm',
#  101: 'Air Transport International',
#  102: 'Agip',
#  103: 'Fun Dip',
#  104: 'Unox',
#  105: 'Munch',
#  106: 'Nikon',
#  107: 'Asahi',
#  108: 'Argosy',
#  109: "French's",
#  110: 'Starbucks',
#  111: 'Sultana Bran',
#  112: "Gale's",
#  113: 'TIGI',
#  114: 'Carrefour',
#  115: 'Kecap Bango',
#  116: 'Coca-Cola Zero',
#  117: 'LG',
#  118: 'Dyno-Bites',
#  119: "Tom's of Maine",
#  120: 'Amoi',
#  121: "Cracker Jack'",
#  122: 'CoverGirl',
#  123: 'Nicorette',
#  124: 'Nehi',
#  125: "Swensen's",
#  126: 'Handi-Snacks',
#  127: 'HB',
#  128: 'Marshall',
#  129: 'Dr Pepper',
#  130: 'Remington',
#  131: 'Cape Cod Potato Chips',
#  132: 'Bushnell',
#  133: 'Batman',
#  134: 'BAC',
#  135: 'Excalibur',
#  136: 'HMT',
#  137: 'Nutri-Grain',
#  138: 'Star Energy',
#  139: 'Berlin & Racycle',
#  140: 'Keystone Ice',
#  141: 'Transcom',
#  142: 'Audar',
#  143: 'Brother',
#  144: 'Dove',
#  145: 'Twinkles',
#  146: 'Lancia',
#  147: 'Rovio',
#  148: 'Imperial',
#  149: "Krusty-O's",
#  150: 'Alfa Romeo',
#  151: 'Krush',
#  152: 'chanel',
#  153: 'Magnafon',
#  154: 'Chocapic',
#  155: 'Liberty',
#  156: 'OPL',
#  157: 'Big Boy',
#  158: 'Grundig',
#  159: 'Barista Lavazza',
#  160: 'Kogan',
#  161: 'LifeSize',
#  162: 'Orthaheel',
#  163: 'Rexel',
#  164: 'Oceanic',
#  165: 'Uny',
#  166: 'The Pizza Company',
#  167: 'Shoprite',
#  168: 'Getty',
#  169: 'Chopard',
#  170: 'MP',
#  171: 'Aquapod',
#  172: 'ALCO',
#  173: 'Hammary',
#  174: 'Ultima',
#  175: 'Tata',
#  176: 'La Flor Dominicana',
#  177: 'Pillsbury',
#  178: 'Pocari Sweat',
#  179: 'Sunsilk',
#  180: 'Loacker',
#  181: 'Tim Hortons',
#  182: 'La Choy',
#  183: 'Indian',
#  184: 'ScotRail',
#  185: 'Stayfree',
#  186: 'Three A',
#  187: 'Sinclair',
#  188: 'Mad River',
#  189: 'Eureka',
#  190: 'Crunchy Corn Bran',
#  191: 'Orbit',
#  192: 'Glee Gum',
#  193: 'De Rosa',
#  194: 'DIA',
#  195: 'Lotus',
#  196: 'Vargas',
#  197: 'Wellington',
#  198: 'muyingzhijia',
#  199: 'Oatibix',
#  200: 'Nesquik',
#  201: 'Count Chocula',
#  202: 'Douwe Egberts',
#  203: 'Centurion',
#  204: 'Matt',
#  205: 'Auchan',
#  206: 'Lloyd',
#  207: 'Ace Cider',
#  208: 'Ricoh',
#  209: 'Boses',
#  210: 'Wild',
#  211: 'Nascar',
#  212: 'Vulcan',
#  213: "Nice 'n Easy",
#  214: 'Stars',
#  215: 'Alfa',
#  216: 'Carmel I',
#  217: 'Chery',
#  218: 'Meswak',
#  219: 'Lefevre-Utile',
#  220: 'Annapurna',
#  221: 'Dentyne',
#  222: 'DARLIE',
#  223: 'Marussia',
#  224: 'Wuliangye',
#  225: 'Podravka',
#  226: 'TSMC',
#  227: 'Curtis',
#  228: 'Ice',
#  229: "MaggieMoo's Ice Cream and Treatery",
#  230: 'SweeTarts',
#  231: 'woolworths',
#  232: 'Scotch',
#  233: 'Big League',
#  234: 'Pennzoil',
#  235: 'Sony Ericsson',
#  236: 'Circa',
#  237: 'Ariel',
#  238: 'Weet-Bix',
#  239: 'PG',
#  240: 'Romika',
#  241: 'Mirage',
#  242: 'Nippon',
#  243: 'BP',
#  244: 'Alpine',
#  245: 'Micro',
#  246: 'PBS',
#  247: 'Newark',
#  248: "Shoney's",
#  249: 'Montblanc',
#  250: 'Soundwave',
#  251: 'Sector',
#  252: 'Baby Ruth',
#  253: 'haagen-dazs',
#  254: 'Chubbys',
#  255: 'Tesla',
#  256: 'Miranda',
#  257: 'Bandit',
#  258: 'Ed Hardy',
#  259: 'Nilla',
#  260: 'Pringles',
#  261: 'Buddy',
#  262: 'Mercedes-Benz',
#  263: 'TUC',
#  264: 'Alsa',
#  265: 'Mickey Mouse',
#  266: 'Tayto Fusion',
#  267: "Boscov's",
#  268: 'Red Rock',
#  269: 'Vim',
#  270: 'Yinlu Food',
#  271: 'Master',
#  272: 'Stretch Island Fruit',
#  273: 'Mr. Potatohead',
#  274: 'Pep',
#  275: "Zaxby's",
#  276: 'Snapz Crisps',
#  277: 'Alhambra',
#  278: 'Luhua',
#  279: 'Mongoose',
#  280: "Peet's Coffee & Tea",
#  281: 'Ask',
#  282: 'Limca',
#  283: 'Al Manhal',
#  284: 'Applek',
#  285: 'Tretorn',
#  286: 'Honey Graham',
#  287: 'Nerds Rope',
#  288: 'G-Star',
#  289: 'Heartland',
#  290: 'HP Sauce',
#  291: 'Banania',
#  292: 'Golden Grahams',
#  293: 'Muzz Buzz',
#  294: 'Maxibon',
#  295: 'Carte Noire',
#  296: 'Minolta',
#  297: 'nokia',
#  298: 'QINGHUA',
#  299: 'Kool-Aid',
#  300: 'Microsoft',
#  301: 'Contec',
#  302: 'St Ives',
#  303: 'Vans',
#  304: 'AOC',
#  305: 'Monster Energy',
#  306: 'Ginger Ale',
#  307: 'ABLE',
#  308: 'Meopta',
#  309: 'Zenith',
#  310: 'Fred Meyer',
#  311: "Sainsbury's",
#  312: 'Nelson',
#  313: 'Volvo',
#  314: 'REFOSIAN',
#  315: 'Red Barn',
#  316: 'Globe',
#  317: 'Appletiser',
#  318: 'Mountain Dew',
#  319: 'Honey Nut Cheerios',
#  320: 'Abuelita',
#  321: 'Petronas',
#  322: 'The Halal',
#  323: 'Cows',
#  324: 'DY',
#  325: "Macy's",
#  326: 'Smash',
#  327: 'TVR',
#  328: 'Supreme',
#  329: 'Tombstone',
#  330: 'Aqua Mineral',
#  331: 'Intel',
#  332: 'Wonka',
#  333: 'Reliv',
#  334: 'Sunny Delight',
#  335: 'Super 8',
#  336: 'Oliva',
#  337: 'Cat in the Hat',
#  338: 'Chevron',
#  339: 'Aquafresh',
#  340: 'Digital',
#  341: 'Ibex',
#  342: 'Clinic',
#  343: 'GMC',
#  344: 'Prince Polo',
#  345: "Pick 'N Pay",
#  346: 'Segafredo',
#  347: 'Delta',
#  348: 'Start',
#  349: 'PDV',
#  350: 'Bottle Caps',
#  351: 'Koenigsegg',
#  352: 'Nike',
#  353: 'Skippy',
#  354: 'Ambrosia',
#  355: 'Colonial1',
#  356: "Fruit 'n Fibre",
#  357: 'Quoizel',
#  358: 'Fuji Xerox',
#  359: 'J2O',
#  360: 'Double Chocolate Cookie Crisp',
#  361: 'Dawn',
#  362: 'Black Jack',
#  363: 'YES!',
#  364: 'Skinny Cow',
#  365: 'KR3W',
#  366: 'California',
#  367: 'Dunhill',
#  368: 'Eskimo',
#  369: 'Guojiao',
#  370: 'Molson Canadian',
#  371: 'Philco',
#  372: 'Fabrica',
#  373: 'Belk',
#  374: 'Freebirds',
#  375: 'Chocolate Krave',
#  376: 'Fairtex',
#  377: 'Olmo',
#  378: 'Sharpie',
#  379: 'TIANCAI',
#  380: '100 anos',
#  381: 'Casio',
#  382: 'KFC',
#  383: 'Wheat Thins',
#  384: 'Princessa',
#  385: 'Shredded Oats',
#  386: 'Red Hot & Blue',
#  387: "Long John Silver's",
#  388: 'Converse',
#  389: 'Currys',
#  390: 'Sizzler',
#  391: 'Sugar Crisp',
#  392: "Marie Callender's",
#  393: 'Excel',
#  394: 'Cargills',
#  395: 'Mr.Muscle',
#  396: 'Pita Pit',
#  397: 'Cerelac',
#  398: 'Snickers',
#  399: 'PizzaExpress',
#  400: 'Marathon Petroleum',
#  401: 'Alonso Menendez',
#  402: 'smart',
#  403: 'Gobstoppers',
#  404: 'Brick',
#  405: 'yanjing',
#  406: 'Dell',
#  407: "Hershey's Cookies 'n' Creme",
#  408: 'Ricola',
#  409: 'Technics',
#  410: 'Refreshers Gums',
#  411: 'Rembrandt toothpaste',
#  412: 'Papillio',
#  413: 'Domenico',
#  414: 'Contax',
#  415: 'Monster',
#  416: 'Pirates',
#  417: 'Meindl',
#  418: "Dreyer's",
#  419: 'ECS',
#  420: 'Tim Tam',
#  421: 'Universal',
#  422: 'Ecco',
#  423: 'Backwoods',
#  424: 'Cheer',
#  425: 'Strada',
#  426: 'Allbright',
#  427: 'Raisin Bran',
#  428: 'Nestle Ski',
#  429: 'Valdez',
#  430: 'OKQ8',
#  431: 'Balance',
#  432: 'Barracuda',
#  433: 'Murphy',
#  434: 'Consort',
#  435: 'Cascadian Farm',
#  436: 'Aopen',
#  437: 'Pac-Man',
#  438: 'PAM',
#  439: 'Connaught',
#  440: 'LOTOS',
#  441: 'Sealtest',
#  442: 'Mendocino',
#  443: 'Paper Mate',
#  444: 'Panama',
#  445: 'AXA',
#  446: 'Milwaukee',
#  447: 'Knorr',
#  448: "Oh's",
#  449: 'Frosties',
#  450: 'WESCO',
#  451: 'Sunbeam',
#  452: 'Old Spice',
#  453: 'D&S',
#  454: 'BEL',
#  455: 'Candle',
#  456: 'Aim',
#  457: 'Ashbury',
#  458: 'Kroger',
#  459: 'Ultra',
#  460: 'Acqua Panna',
#  461: 'Rail Road tracks',
#  462: 'Montague',
#  463: 'Avene',
#  464: 'Lone Star Steakhouse & Saloon',
#  465: 'Tiffin',
#  466: 'Saga',
#  467: 'Milka',
#  468: 'Sunce',
#  469: 'Ashton',
#  470: 'SCOTT',
#  471: "Frankie & Benny's",
#  472: 'Dor',
#  473: 'La Aroma de Cuba',
#  474: 'Westfield',
#  475: 'Nespresso',
#  476: 'Oscar Mayer',
#  477: 'SAKURA',
#  478: 'Gremlins',
#  479: 'Rainbow Brite',
#  480: 'Corn Pops',
#  481: 'Ascari',
#  482: 'Tauro',
#  483: 'Thomas',
#  484: 'Liancheng',
#  485: 'Quake',
#  486: 'Braun',
#  487: 'CHS',
#  488: 'Marsh Wheeling',
#  489: 'Montclair',
#  490: 'Metz',
#  491: 'Thorntons',
#  492: 'Hunor',
#  493: 'Mr Kipling',
#  494: 'Gibbs',
#  495: 'Tree Top',
#  496: 'Pro Plan',
#  497: 'Stage',
#  498: 'Nan',
#  499: 'LIVESCRIBE',
#  500: 'Kid Cuisine',
#  501: 'Anitech',
#  502: 'Heat',
#  503: 'pepsi',
#  504: 'Amoco',
#  505: 'Crayola',
#  506: 'Escada',
#  507: 'Milkybar',
#  508: 'Genius',
#  509: 'Transcend',
#  510: 'Amkette',
#  511: 'Accel',
#  512: 'Derwent',
#  513: 'Vredestein',
#  514: 'Olay',
#  515: 'Medion',
#  516: 'Maple & Brown',
#  517: 'Nostromo',
#  518: 'SVA',
#  519: 'Lamborghini',
#  520: 'Daihatsu',
#  521: 'Celestial Seasonings',
#  522: 'Eastpak',
#  523: 'Detroit',
#  524: 'JAC',
#  525: "Barq's",
#  526: 'Honey Kix',
#  527: 'Base',
#  528: 'ExpressJet',
#  529: 'Perugina Baci',
#  530: 'Goya',
#  531: 'Columbia',
#  532: 'TMA',
#  533: 'Mondia',
#  534: 'Estrella',
#  535: 'sun',
#  536: 'Shake Junt',
#  537: 'GoldStar',
#  538: 'Emo',
#  539: 'Picnic',
#  540: "Richard Petty 43's",
#  541: 'TCL',
#  542: 'Pik-Nik',
#  543: 'Twistee Treat',
#  544: 'Advent',
#  545: 'Allorgan',
#  546: 'Gillette',
#  547: 'Butterkist',
#  548: 'Santander',
#  549: 'Shreddies',
#  550: 'Quiksilver',
#  551: 'Nail',
#  552: 'oppo',
#  553: 'Audi',
#  554: 'Givova',
#  555: 'Bang & Olufsen',
#  556: 'Tamarind',
#  557: 'Heinz Baked Beans',
#  558: 'Lares Ice Cream Parlor',
#  559: 'Pizza California',
#  560: 'Galp',
#  561: 'Nickelodeon',
#  562: 'Peppersmith',
#  563: 'Mojos',
#  564: 'Radox',
#  565: 'BSA',
#  566: 'MARC BY MARC JACOBS',
#  567: 'Tide',
#  568: 'ganzhu',
#  569: 'Pepsodent',
#  570: 'Tab',
#  571: 'Screamers',
#  572: 'Bridgestone',
#  573: 'Aston Martin',
#  574: 'Dignity',
#  575: 'Franken Berry',
#  576: 'Maynards',
#  577: 'Cannondale',
#  578: 'Haier',
#  579: 'Xtep',
#  580: 'Antonius',
#  581: 'Special K',
#  582: 'Casino',
#  583: 'BMC',
#  584: 'Luxor',
#  585: "LLoyd's",
#  586: 'Espolon',
#  587: 'Trek Bicycle',
#  588: 'Marriott International',
#  589: 'Tec',
#  590: 'Opal',
#  591: 'E.T',
#  592: 'BiFi',
#  593: 'Frosted Krispies',
#  594: 'Nestle Crunch',
#  595: 'Squirt',
#  596: 'Smurf Berry Crunch',
#  597: 'Jeep',
#  598: 'SITIR LIQUOR CO',
#  599: "Van Camp's",
#  600: 'GT Bicycles',
#  601: 'Kingsley',
#  602: 'Cocoa Krispies',
#  603: 'Molson',
#  604: 'Yahoo! Messenger',
#  605: 'Reef',
#  606: 'Stanley',
#  607: 'Cream of Wheat',
#  608: 'Runza',
#  609: 'Little Caesars',
#  610: 'Element',
#  611: 'yanghe',
#  612: 'Donkey Kong',
#  613: 'Nelly',
#  614: 'Red Bull',
#  615: 'Phase One',
#  616: 'IHOP',
#  617: 'Steam Whistle',
#  618: 'Butterfinger Crisp',
#  619: 'Pampers & Pampers Kandoo',
#  620: 'Captain Morgan',
#  621: 'Snoopy Sno-Cone',
#  622: 'Weaver',
#  623: 'Cauldron',
#  624: 'Tracker',
#  625: 'Wagner',
#  626: 'Rex',
#  627: 'Sainte',
#  628: 'Highland Spring',
#  629: 'Walmart',
#  630: 'Pilot',
#  631: 'Strongbow',
#  632: 'G.I. Joe Action Stars',
#  633: 'White Castle',
#  634: 'Nestum',
#  635: 'Caro',
#  636: 'Air Cargo Carriers',
#  637: 'Paris',
#  638: 'Linc',
#  639: 'Amp',
#  640: 'Kinder',
#  641: 'Black Label Skateboards',
#  642: 'jinlongyu',
#  643: 'Nissin',
#  644: 'Beaulieu',
#  645: 'Marvel',
#  646: 'FUJITSU',
#  647: 'Badedas',
#  648: 'Astro',
#  649: 'Marmite',
#  650: 'Poland Spring',
#  651: 'jinsangzi',
#  652: 'Solex',
#  653: 'Nestle',
#  654: 'Tyrrells Apple Chips',
#  655: 'Dunlop',
#  656: 'Iams',
#  657: 'Overland',
#  658: 'Uiltje',
#  659: 'Bilisten',
#  660: 'Cool Whip',
#  661: 'Realtor',
#  662: 'Granada',
#  663: 'Intermarche',
#  664: 'The Batman',
#  665: 'San Miguel',
#  666: 'Lego',
#  667: 'Mintad',
#  668: 'Great Wall',
#  669: 'Mavic',
#  670: 'Oops All Berries',
#  671: 'Premium',
#  672: 'Sugar Sprinkled Twinkles',
#  673: 'AVON',
#  674: 'Seasons 52',
#  675: 'SnackWells',
#  676: 'yanlaihong',
#  677: 'AERIAL7',
#  678: 'AC',
#  679: 'Esquires',
#  680: '24seven',
#  681: 'Carnation (brand)',
#  682: 'Vana Tallinn',
#  683: 'Kinnie',
#  684: 'Tetley',
#  685: 'Telepizza',
#  686: 'Sunstar',
#  687: 'VH',
#  688: 'coles',
#  689: 'BOSCH',
#  690: 'Neckermann',
#  691: 'La Perla',
#  692: 'Rice Krispies',
#  693: 'Savory',
#  694: 'Cabana',
#  695: "Uncle Joe's Mint Balls",
#  696: 'Sysline',
#  697: 'Connector',
#  698: 'Pokemon',
#  699: 'Emerica',
#  700: "Hardee's",
#  701: 'Radio Flyer',
#  702: 'TECO',
#  703: 'Toronto',
#  704: 'Amstrad',
#  705: 'JS',
#  706: 'Hoffmann',
#  707: 'Lagunitas',
#  708: 'Gel',
#  709: "Totino's",
#  710: 'Lanka',
#  711: 'General Electric',
#  712: 'Hancock',
#  713: 'Basil',
#  714: 'Costa Coffee',
#  715: 'Nido',
#  716: 'Estuary',
#  717: 'Hot Pockets',
#  718: 'Ipso',
#  719: 'Dawa',
#  720: 'Lane Furniture',
#  721: 'Polaroid',
#  722: 'Oronamin C',
#  723: 'Savage',
#  724: 'Mirc',
#  725: 'Dollar Tree',
#  726: 'Hitachi1',
#  727: 'Always',
#  728: 'Unicef',
#  729: 'La Laitiere',
#  730: 'High School Musical',
#  731: 'Cosi',
#  732: 'Peter Pan',
#  733: 'R&I',
#  734: 'Shaw',
#  735: 'Kraft Eating Right',
#  736: 'MultiGrain Cheerios',
#  737: 'Oat Crisp',
#  738: 'Valero',
#  739: 'La Escepcion',
#  740: 'Heaven_',
#  741: 'Singer',
#  742: 'SHINETIME',
#  743: 'Britannia',
#  744: 'Caltex',
#  745: 'Frosted Flakes',
#  746: 'DVS Shoes',
#  747: 'Paz',
#  748: 'Alpen Gold',
#  749: 'Molson Dry',
#  750: 'MICROPLANE',
#  751: 'Dyson',
#  752: 'Avion',
#  753: "Copeland's",
#  754: 'Aquafina',
#  755: 'Irn Bru Bar',
#  756: 'Cheaders',
#  757: 'Alpha-Bits',
#  758: 'Timotei',
#  759: 'Fruit of the Loom',
#  760: 'Usha',
#  761: 'Cello',
#  762: 'Harvest Moon',
#  763: 'Ted Drewes',
#  764: 'Klogs',
#  765: 'Tesco',
#  766: 'Wipro',
#  767: 'Georgia Boot',
#  768: 'Sampo',
#  769: 'Lane',
#  770: 'Boston Market',
#  771: 'Zamberlan',
#  772: 'Litespeed',
#  773: 'Blue Sky',
#  774: 'Maizena',
#  775: 'Jamba Juice',
#  776: 'Noodles & Company',
#  777: 'Prize',
#  778: 'Buick',
#  779: 'Victoria',
#  780: 'KAWASAKI',
#  781: 'Quality',
#  782: 'Tidy Cats',
#  783: 'Noble',
#  784: 'Motobecane',
#  785: 'Allegiant Air',
#  786: 'ConAgra Foods',
#  787: 'BMW',
#  788: 'Toy Machine',
#  789: 'CTS',
#  790: "Lyon's",
#  791: 'Benelli',
#  792: 'Freightliner',
#  793: 'Extra',
#  794: 'Koko Krunch',
#  795: 'Sea & Sea',
#  796: 'Impact',
#  797: 'Abici',
#  798: 'Isuzu',
#  799: 'SNOOPY',
#  800: 'BCP',
#  801: 'Alec Bradley',
#  802: 'Java',
#  803: 'aceh',
#  804: 'Amazon at Lab126',
#  805: 'Wonka Bars',
#  806: 'Che',
#  807: 'Waterman',
#  808: 'Andrea Electronics',
#  809: 'Frontier',
#  810: 'Lucky',
#  811: 'Orion',
#  812: 'Pearson',
#  813: 'KINGSTON',
#  814: 'Capri',
#  815: 'Walkers Shortbread',
#  816: 'Belvita',
#  817: 'Walch',
#  818: 'vatti',
#  819: 'Cosan',
#  820: 'Black Angus Steakhouse',
#  821: 'Twix',
#  822: 'niulanghan',
#  823: 'BLACKBERRY',
#  824: 'cestbon',
#  825: 'Lakefront',
#  826: 'Bold',
#  827: 'MG',
#  828: 'Astor',
#  829: 'Marshmallow',
#  830: 'Colinas',
#  831: "Terry's",
#  832: 'Rahr',
#  833: 'Norco',
#  834: 'Orbea',
#  835: 'AirTran Airways',
#  836: 'Beacon',
#  837: 'Twin Peaks',
#  838: 'Beko',
#  839: 'Ruger',
#  840: 'Olmeca',
#  841: 'Cheerios',
#  842: 'All-Bran',
#  843: "Arby's",
#  844: 'Project Eden',
#  845: 'Boulder',
#  846: 'BACCARAT',
#  847: 'Uno Chicago Grill',
#  848: 'Steyr',
#  849: 'Ross',
#  850: 'CHEF',
#  851: 'hp',
#  852: 'La Palina',
#  853: 'Conimex',
#  854: 'Coronaa',
#  855: 'Esso',
#  856: 'The Simpsons',
#  857: 'BaiDu',
#  858: 'Sure',
#  859: "Bird's Custard",
#  860: 'Quorum',
#  861: "Murphy's",
#  862: 'Bluegrass',
#  863: 'Daewoo',
#  864: 'Nintendo',
#  865: 'Kirkland Signature',
#  866: 'Harrison',
#  867: 'Gota',
#  868: 'Oki',
#  869: 'Diana',
#  870: 'Buitoni',
#  871: 'Kitkat',
#  872: 'Punch',
#  873: 'Solo',
#  874: 'Texas Instruments',
#  875: 'Sodastream',
#  876: 'Shell',
#  877: 'Extreme',
#  878: 'Best Western Hotels',
#  879: 'Orlen',
#  880: 'Ilford Photo',
#  881: 'Kins',
#  882: 'Capital',
#  883: 'Clement',
#  884: 'Bru',
#  885: 'Phillies',
#  886: 'Blue Hills',
#  887: 'Eukanuba',
#  888: 'Aspen Home',
#  889: 'CMC',
#  890: 'Mumtaz',
#  891: 'Paragon Pictures',
#  892: 'Vive',
#  893: 'Beneful',
#  894: "Shrek's",
#  895: 'Hot Wheels',
#  896: 'eMachines',
#  897: 'Creemore',
#  898: 'Cisco Systems',
#  899: 'Musashi',
#  900: 'Pathe',
#  901: 'Root Beer',
#  902: 'Black Horse',
#  903: 'Gambit',
#  904: 'Transformers',
#  905: 'Club Social',
#  906: 'Miko',
#  907: "Kwality Wall's",
#  908: 'Birmingham',
#  909: 'Golite',
#  910: 'MINI',
#  911: 'Nestea',
#  912: 'Subway',
#  913: 'Primos',
#  914: 'Sonic Drive-In',
#  915: 'Brut',
#  916: 'Cherry 7Up',
#  917: 'HTC',
#  918: 'Cracker Jack',
#  919: 'Sprecher',
#  920: 'Chicago',
#  921: 'Impulse',
#  922: 'Crazy Cow',
#  923: 'Lacto',
#  924: 'OKs',
#  925: 'Metro AG',
#  926: 'Ricore',
#  927: 'HaiNan Airlines',
#  928: 'Hyundai',
#  929: 'U.S. Traveler',
#  930: 'Kuota',
#  931: 'Colnago',
#  932: 'Kaiser',
#  933: "Cameron's",
#  934: 'Daewoo Electronics',
#  935: "Nobby's Nuts",
#  936: 'Google',
#  937: 'HEC',
#  938: 'Diplomaticos',
#  939: 'Indomie Mi goreng',
#  940: 'BTC',
#  941: 'Suchard',
#  942: 'Uway',
#  943: 'Nestle Drumstick',
#  944: 'Fujitsu',
#  945: 'Circus Fun',
#  946: 'Double Take',
#  947: 'Danish',
#  948: 'TAG Heuer',
#  949: 'Osram Sylvania',
#  950: 'Salewa',
#  951: 'Mojang',
#  952: 'Buxton',
#  953: 'Carling',
#  954: 'Ala',
#  955: 'Ssangyong',
#  956: 'Ducati',
#  957: 'Leica',
#  958: 'Double Chocolate Krave',
#  959: 'American Star Bicycle',
#  960: 'ANCAP',
#  961: 'Coffee-Mate',
#  962: "Sarson's",
#  963: 'Specialized',
#  964: 'El Jimador',
#  965: 'Sauza',
#  966: 'RedDragnfly',
#  967: 'BH',
#  968: 'Nestle NesQuik',
#  969: 'Tres',
#  970: 'Kah Tequila',
#  971: 'Porsche',
#  972: 'Traveler',
#  973: 'St',
#  974: 'Kross',
#  975: 'Sanyo',
#  976: 'Manhattan Portage',
#  977: 'Johnson & Johnson',
#  978: 'Kapsch',
#  979: 'Aqua Spring',
#  980: 'Frito-Lay',
#  981: 'Baker Skateboards',
#  982: 'Molson Export',
#  983: 'Hospitals',
#  984: 'Triscuit',
#  985: "Butterfinger BB's",
#  986: 'Padron',
#  987: 'Dolce & Gabbana',
#  988: 'Diesel',
#  989: 'Angry Orchard',
#  990: 'Asus',
#  991: 'Naleczowianka',
#  992: 'MarsInc',
#  993: 'AICO',
#  994: 'Mossberg',
#  995: 'PerkinElmer',
#  996: 'Boo Berry',
#  997: 'Yellow Cab Pizza Co',
#  998: 'Dubble Bubble',
#  999: 'Deer Park',
#  ...}

# %%
new_train
# Out:
# {0: 'Scholler',
#  1: 'Oreo',
#  2: 'Mist',
#  3: 'McCafe',
#  4: 'Frosted Toast Crunch',
#  5: 'KP Nuts',
#  6: "Smith's Crisps",
#  7: 'Nine West',
#  8: 'Butterfinger Bites',
#  9: 'Kix',
#  10: 'Top',
#  11: 'H. J. Heinz',
#  12: 'Akubra',
#  13: 'Marmara',
#  14: 'Standard',
#  15: 'Karma',
#  16: 'Tropicana',
#  17: 'Gateway',
#  18: 'La Vie',
#  19: "Reese's Puffs",
#  20: 'Calvin Klein',
#  21: 'PG Tips',
#  22: 'Cathay',
#  23: 'Vittel',
#  24: 'Amora',
#  25: 'Pertamina',
#  26: 'Texas Roadhouse',
#  27: 'Rima',
#  28: 'Kent',
#  29: 'Neutral',
#  30: 'saky',
#  31: 'Campbells',
#  32: 'J. Lancaster & Son',
#  33: 'The Real Deal',
#  34: 'DC Shoes',
#  35: 'Elf',
#  36: 'Buffalo Rock Ginger Ale',
#  37: 'Mr Greedy',
#  38: 'Senator',
#  39: 'Choice Hotels',
#  40: 'Breath Savers',
#  41: 'Domus',
#  42: 'Bassett',
#  43: 'Liga',
#  44: 'Julmust',
#  45: 'Vimto',
#  46: 'SUNING',
#  47: 'Molson Canadian 67',
#  48: 'Organic Wild Puffs',
#  49: 'Schweppes Tonic',
#  50: 'Kern',
#  51: "Newman's Own",
#  52: 'Life is good',
#  53: 'Supra',
#  54: 'Crown',
#  55: 'Persil',
#  56: 'Los Angeles',
#  57: 'Coco Pops',
#  58: 'Albertsons',
#  59: 'Leed',
#  60: 'SBR',
#  61: 'DMC',
#  62: 'Marble Slab Creamery',
#  63: 'Avanti',
#  64: 'Corn Flakes',
#  65: 'Bona',
#  66: 'Ameristar Jet Charter',
#  67: "Birki's",
#  68: 'Chiclets',
#  69: 'Aztec',
#  70: 'Cocio',
#  71: 'Aiptek',
#  72: 'MAD DOG',
#  73: 'Monster Moca',
#  74: 'Snapple',
#  75: 'Peerless',
#  76: 'kepeng',
#  77: 'Pure',
#  78: 'Gazelle',
#  79: 'MONDI',
#  80: "Shakey's Pizza",
#  81: 'Trio',
#  82: 'Lifan',
#  83: 'Mountain Equipment',
#  84: 'Thomson',
#  85: 'Colonial',
#  86: 'D-Link',
#  87: 'Jiaozhou',
#  88: 'La Aurora',
#  89: 'Swiss',
#  90: 'Axe',
#  91: 'Ellesse',
#  92: 'Toby',
#  93: 'Origins',
#  94: 'Charmin',
#  95: 'Breguet',
#  96: 'Acer',
#  97: 'ROSLE',
#  98: 'Landwind',
#  99: 'La Gloria Cubana',
#  100: 'Arm',
#  101: 'Air Transport International',
#  102: 'Agip',
#  103: 'Fun Dip',
#  104: 'Unox',
#  105: 'Munch',
#  106: 'Nikon',
#  107: 'Asahi',
#  108: 'Argosy',
#  109: "French's",
#  110: 'Starbucks',
#  111: 'Sultana Bran',
#  112: "Gale's",
#  113: 'TIGI',
#  114: 'Carrefour',
#  115: 'Kecap Bango',
#  116: 'Coca-Cola Zero',
#  117: 'LG',
#  118: 'Dyno-Bites',
#  119: "Tom's of Maine",
#  120: 'Amoi',
#  121: "Cracker Jack'",
#  122: 'CoverGirl',
#  123: 'Nicorette',
#  124: 'Nehi',
#  125: "Swensen's",
#  126: 'Handi-Snacks',
#  127: 'HB',
#  128: 'Marshall',
#  129: 'Dr Pepper',
#  130: 'Remington',
#  131: 'Cape Cod Potato Chips',
#  132: 'Bushnell',
#  133: 'Batman',
#  134: 'BAC',
#  135: 'Excalibur',
#  136: 'HMT',
#  137: 'Nutri-Grain',
#  138: 'Star Energy',
#  139: 'Berlin & Racycle',
#  140: 'Keystone Ice',
#  141: 'Transcom',
#  142: 'Audar',
#  143: 'Brother',
#  144: 'Dove',
#  145: 'Twinkles',
#  146: 'Lancia',
#  147: 'Rovio',
#  148: 'Imperial',
#  149: "Krusty-O's",
#  150: 'Alfa Romeo',
#  151: 'Krush',
#  152: 'chanel',
#  153: 'Magnafon',
#  154: 'Chocapic',
#  155: 'Liberty',
#  156: 'OPL',
#  157: 'Big Boy',
#  158: 'Grundig',
#  159: 'Barista Lavazza',
#  160: 'Kogan',
#  161: 'LifeSize',
#  162: 'Orthaheel',
#  163: 'Rexel',
#  164: 'Oceanic',
#  165: 'Uny',
#  166: 'The Pizza Company',
#  167: 'Shoprite',
#  168: 'Getty',
#  169: 'Chopard',
#  170: 'MP',
#  171: 'Aquapod',
#  172: 'ALCO',
#  173: 'Hammary',
#  174: 'Ultima',
#  175: 'Tata',
#  176: 'La Flor Dominicana',
#  177: 'Pillsbury',
#  178: 'Pocari Sweat',
#  179: 'Sunsilk',
#  180: 'Loacker',
#  181: 'Tim Hortons',
#  182: 'La Choy',
#  183: 'Indian',
#  184: 'ScotRail',
#  185: 'Stayfree',
#  186: 'Three A',
#  187: 'Sinclair',
#  188: 'Mad River',
#  189: 'Eureka',
#  190: 'Crunchy Corn Bran',
#  191: 'Orbit',
#  192: 'Glee Gum',
#  193: 'De Rosa',
#  194: 'DIA',
#  195: 'Lotus',
#  196: 'Vargas',
#  197: 'Wellington',
#  198: 'muyingzhijia',
#  199: 'Oatibix',
#  200: 'Nesquik',
#  201: 'Count Chocula',
#  202: 'Douwe Egberts',
#  203: 'Centurion',
#  204: 'Matt',
#  205: 'Auchan',
#  206: 'Lloyd',
#  207: 'Ace Cider',
#  208: 'Ricoh',
#  209: 'Boses',
#  210: 'Wild',
#  211: 'Nascar',
#  212: 'Vulcan',
#  213: "Nice 'n Easy",
#  214: 'Stars',
#  215: 'Alfa',
#  216: 'Carmel I',
#  217: 'Chery',
#  218: 'Meswak',
#  219: 'Lefevre-Utile',
#  220: 'Annapurna',
#  221: 'Dentyne',
#  222: 'DARLIE',
#  223: 'Marussia',
#  224: 'Wuliangye',
#  225: 'Podravka',
#  226: 'TSMC',
#  227: 'Curtis',
#  228: 'Ice',
#  229: "MaggieMoo's Ice Cream and Treatery",
#  230: 'SweeTarts',
#  231: 'woolworths',
#  232: 'Scotch',
#  233: 'Big League',
#  234: 'Pennzoil',
#  235: 'Sony Ericsson',
#  236: 'Circa',
#  237: 'Ariel',
#  238: 'Weet-Bix',
#  239: 'PG',
#  240: 'Romika',
#  241: 'Mirage',
#  242: 'Nippon',
#  243: 'BP',
#  244: 'Alpine',
#  245: 'Micro',
#  246: 'PBS',
#  247: 'Newark',
#  248: "Shoney's",
#  249: 'Montblanc',
#  250: 'Soundwave',
#  251: 'Sector',
#  252: 'Baby Ruth',
#  253: 'haagen-dazs',
#  254: 'Chubbys',
#  255: 'Tesla',
#  256: 'Miranda',
#  257: 'Bandit',
#  258: 'Ed Hardy',
#  259: 'Nilla',
#  260: 'Pringles',
#  261: 'Buddy',
#  262: 'Mercedes-Benz',
#  263: 'TUC',
#  264: 'Alsa',
#  265: 'Mickey Mouse',
#  266: 'Tayto Fusion',
#  267: "Boscov's",
#  268: 'Red Rock',
#  269: 'Vim',
#  270: 'Yinlu Food',
#  271: 'Master',
#  272: 'Stretch Island Fruit',
#  273: 'Mr. Potatohead',
#  274: 'Pep',
#  275: "Zaxby's",
#  276: 'Snapz Crisps',
#  277: 'Alhambra',
#  278: 'Luhua',
#  279: 'Mongoose',
#  280: "Peet's Coffee & Tea",
#  281: 'Ask',
#  282: 'Limca',
#  283: 'Al Manhal',
#  284: 'Applek',
#  285: 'Tretorn',
#  286: 'Honey Graham',
#  287: 'Nerds Rope',
#  288: 'G-Star',
#  289: 'Heartland',
#  290: 'HP Sauce',
#  291: 'Banania',
#  292: 'Golden Grahams',
#  293: 'Muzz Buzz',
#  294: 'Maxibon',
#  295: 'Carte Noire',
#  296: 'Minolta',
#  297: 'nokia',
#  298: 'QINGHUA',
#  299: 'Kool-Aid',
#  300: 'Microsoft',
#  301: 'Contec',
#  302: 'St Ives',
#  303: 'Vans',
#  304: 'AOC',
#  305: 'Monster Energy',
#  306: 'Ginger Ale',
#  307: 'ABLE',
#  308: 'Meopta',
#  309: 'Zenith',
#  310: 'Fred Meyer',
#  311: "Sainsbury's",
#  312: 'Nelson',
#  313: 'Volvo',
#  314: 'REFOSIAN',
#  315: 'Red Barn',
#  316: 'Globe',
#  317: 'Appletiser',
#  318: 'Mountain Dew',
#  319: 'Honey Nut Cheerios',
#  320: 'Abuelita',
#  321: 'Petronas',
#  322: 'The Halal',
#  323: 'Cows',
#  324: 'DY',
#  325: "Macy's",
#  326: 'Smash',
#  327: 'TVR',
#  328: 'Supreme',
#  329: 'Tombstone',
#  330: 'Aqua Mineral',
#  331: 'Intel',
#  332: 'Wonka',
#  333: 'Reliv',
#  334: 'Sunny Delight',
#  335: 'Super 8',
#  336: 'Oliva',
#  337: 'Cat in the Hat',
#  338: 'Chevron',
#  339: 'Aquafresh',
#  340: 'Digital',
#  341: 'Ibex',
#  342: 'Clinic',
#  343: 'GMC',
#  344: 'Prince Polo',
#  345: "Pick 'N Pay",
#  346: 'Segafredo',
#  347: 'Delta',
#  348: 'Start',
#  349: 'PDV',
#  350: 'Bottle Caps',
#  351: 'Koenigsegg',
#  352: 'Nike',
#  353: 'Skippy',
#  354: 'Ambrosia',
#  355: 'Colonial1',
#  356: "Fruit 'n Fibre",
#  357: 'Quoizel',
#  358: 'Fuji Xerox',
#  359: 'J2O',
#  360: 'Double Chocolate Cookie Crisp',
#  361: 'Dawn',
#  362: 'Black Jack',
#  363: 'YES!',
#  364: 'Skinny Cow',
#  365: 'KR3W',
#  366: 'California',
#  367: 'Dunhill',
#  368: 'Eskimo',
#  369: 'Guojiao',
#  370: 'Molson Canadian',
#  371: 'Philco',
#  372: 'Fabrica',
#  373: 'Belk',
#  374: 'Freebirds',
#  375: 'Chocolate Krave',
#  376: 'Fairtex',
#  377: 'Olmo',
#  378: 'Sharpie',
#  379: 'TIANCAI',
#  380: '100 anos',
#  381: 'Casio',
#  382: 'KFC',
#  383: 'Wheat Thins',
#  384: 'Princessa',
#  385: 'Shredded Oats',
#  386: 'Red Hot & Blue',
#  387: "Long John Silver's",
#  388: 'Converse',
#  389: 'Currys',
#  390: 'Sizzler',
#  391: 'Sugar Crisp',
#  392: "Marie Callender's",
#  393: 'Excel',
#  394: 'Cargills',
#  395: 'Mr.Muscle',
#  396: 'Pita Pit',
#  397: 'Cerelac',
#  398: 'Snickers',
#  399: 'PizzaExpress',
#  400: 'Marathon Petroleum',
#  401: 'Alonso Menendez',
#  402: 'smart',
#  403: 'Gobstoppers',
#  404: 'Brick',
#  405: 'yanjing',
#  406: 'Dell',
#  407: "Hershey's Cookies 'n' Creme",
#  408: 'Ricola',
#  409: 'Technics',
#  410: 'Refreshers Gums',
#  411: 'Rembrandt toothpaste',
#  412: 'Papillio',
#  413: 'Domenico',
#  414: 'Contax',
#  415: 'Monster',
#  416: 'Pirates',
#  417: 'Meindl',
#  418: "Dreyer's",
#  419: 'ECS',
#  420: 'Tim Tam',
#  421: 'Universal',
#  422: 'Ecco',
#  423: 'Backwoods',
#  424: 'Cheer',
#  425: 'Strada',
#  426: 'Allbright',
#  427: 'Raisin Bran',
#  428: 'Nestle Ski',
#  429: 'Valdez',
#  430: 'OKQ8',
#  431: 'Balance',
#  432: 'Barracuda',
#  433: 'Murphy',
#  434: 'Consort',
#  435: 'Cascadian Farm',
#  436: 'Aopen',
#  437: 'Pac-Man',
#  438: 'PAM',
#  439: 'Connaught',
#  440: 'LOTOS',
#  441: 'Sealtest',
#  442: 'Mendocino',
#  443: 'Paper Mate',
#  444: 'Panama',
#  445: 'AXA',
#  446: 'Milwaukee',
#  447: 'Knorr',
#  448: "Oh's",
#  449: 'Frosties',
#  450: 'WESCO',
#  451: 'Sunbeam',
#  452: 'Old Spice',
#  453: 'D&S',
#  454: 'BEL',
#  455: 'Candle',
#  456: 'Aim',
#  457: 'Ashbury',
#  458: 'Kroger',
#  459: 'Ultra',
#  460: 'Acqua Panna',
#  461: 'Rail Road tracks',
#  462: 'Montague',
#  463: 'Avene',
#  464: 'Lone Star Steakhouse & Saloon',
#  465: 'Tiffin',
#  466: 'Saga',
#  467: 'Milka',
#  468: 'Sunce',
#  469: 'Ashton',
#  470: 'SCOTT',
#  471: "Frankie & Benny's",
#  472: 'Dor',
#  473: 'La Aroma de Cuba',
#  474: 'Westfield',
#  475: 'Nespresso',
#  476: 'Oscar Mayer',
#  477: 'SAKURA',
#  478: 'Gremlins',
#  479: 'Rainbow Brite',
#  480: 'Corn Pops',
#  481: 'Ascari',
#  482: 'Tauro',
#  483: 'Thomas',
#  484: 'Liancheng',
#  485: 'Quake',
#  486: 'Braun',
#  487: 'CHS',
#  488: 'Marsh Wheeling',
#  489: 'Montclair',
#  490: 'Metz',
#  491: 'Thorntons',
#  492: 'Hunor',
#  493: 'Mr Kipling',
#  494: 'Gibbs',
#  495: 'Tree Top',
#  496: 'Pro Plan',
#  497: 'Stage',
#  498: 'Nan',
#  499: 'LIVESCRIBE',
#  500: 'Kid Cuisine',
#  501: 'Anitech',
#  502: 'Heat',
#  503: 'pepsi',
#  504: 'Amoco',
#  505: 'Crayola',
#  506: 'Escada',
#  507: 'Milkybar',
#  508: 'Genius',
#  509: 'Transcend',
#  510: 'Amkette',
#  511: 'Accel',
#  512: 'Derwent',
#  513: 'Vredestein',
#  514: 'Olay',
#  515: 'Medion',
#  516: 'Maple & Brown',
#  517: 'Nostromo',
#  518: 'SVA',
#  519: 'Lamborghini',
#  520: 'Daihatsu',
#  521: 'Celestial Seasonings',
#  522: 'Eastpak',
#  523: 'Detroit',
#  524: 'JAC',
#  525: "Barq's",
#  526: 'Honey Kix',
#  527: 'Base',
#  528: 'ExpressJet',
#  529: 'Perugina Baci',
#  530: 'Goya',
#  531: 'Columbia',
#  532: 'TMA',
#  533: 'Mondia',
#  534: 'Estrella',
#  535: 'sun',
#  536: 'Shake Junt',
#  537: 'GoldStar',
#  538: 'Emo',
#  539: 'Picnic',
#  540: "Richard Petty 43's",
#  541: 'TCL',
#  542: 'Pik-Nik',
#  543: 'Twistee Treat',
#  544: 'Advent',
#  545: 'Allorgan',
#  546: 'Gillette',
#  547: 'Butterkist',
#  548: 'Santander',
#  549: 'Shreddies',
#  550: 'Quiksilver',
#  551: 'Nail',
#  552: 'oppo',
#  553: 'Audi',
#  554: 'Givova',
#  555: 'Bang & Olufsen',
#  556: 'Tamarind',
#  557: 'Heinz Baked Beans',
#  558: 'Lares Ice Cream Parlor',
#  559: 'Pizza California',
#  560: 'Galp',
#  561: 'Nickelodeon',
#  562: 'Peppersmith',
#  563: 'Mojos',
#  564: 'Radox',
#  565: 'BSA',
#  566: 'MARC BY MARC JACOBS',
#  567: 'Tide',
#  568: 'ganzhu',
#  569: 'Pepsodent',
#  570: 'Tab',
#  571: 'Screamers',
#  572: 'Bridgestone',
#  573: 'Aston Martin',
#  574: 'Dignity',
#  575: 'Franken Berry',
#  576: 'Maynards',
#  577: 'Cannondale',
#  578: 'Haier',
#  579: 'Xtep',
#  580: 'Antonius',
#  581: 'Special K',
#  582: 'Casino',
#  583: 'BMC',
#  584: 'Luxor',
#  585: "LLoyd's",
#  586: 'Espolon',
#  587: 'Trek Bicycle',
#  588: 'Marriott International',
#  589: 'Tec',
#  590: 'Opal',
#  591: 'E.T',
#  592: 'BiFi',
#  593: 'Frosted Krispies',
#  594: 'Nestle Crunch',
#  595: 'Squirt',
#  596: 'Smurf Berry Crunch',
#  597: 'Jeep',
#  598: 'SITIR LIQUOR CO',
#  599: "Van Camp's",
#  600: 'GT Bicycles',
#  601: 'Kingsley',
#  602: 'Cocoa Krispies',
#  603: 'Molson',
#  604: 'Yahoo! Messenger',
#  605: 'Reef',
#  606: 'Stanley',
#  607: 'Cream of Wheat',
#  608: 'Runza',
#  609: 'Little Caesars',
#  610: 'Element',
#  611: 'yanghe',
#  612: 'Donkey Kong',
#  613: 'Nelly',
#  614: 'Red Bull',
#  615: 'Phase One',
#  616: 'IHOP',
#  617: 'Steam Whistle',
#  618: 'Butterfinger Crisp',
#  619: 'Pampers & Pampers Kandoo',
#  620: 'Captain Morgan',
#  621: 'Snoopy Sno-Cone',
#  622: 'Weaver',
#  623: 'Cauldron',
#  624: 'Tracker',
#  625: 'Wagner',
#  626: 'Rex',
#  627: 'Sainte',
#  628: 'Highland Spring',
#  629: 'Walmart',
#  630: 'Pilot',
#  631: 'Strongbow',
#  632: 'G.I. Joe Action Stars',
#  633: 'White Castle',
#  634: 'Nestum',
#  635: 'Caro',
#  636: 'Air Cargo Carriers',
#  637: 'Paris',
#  638: 'Linc',
#  639: 'Amp',
#  640: 'Kinder',
#  641: 'Black Label Skateboards',
#  642: 'jinlongyu',
#  643: 'Nissin',
#  644: 'Beaulieu',
#  645: 'Marvel',
#  646: 'FUJITSU',
#  647: 'Badedas',
#  648: 'Astro',
#  649: 'Marmite',
#  650: 'Poland Spring',
#  651: 'jinsangzi',
#  652: 'Solex',
#  653: 'Nestle',
#  654: 'Tyrrells Apple Chips',
#  655: 'Dunlop',
#  656: 'Iams',
#  657: 'Overland',
#  658: 'Uiltje',
#  659: 'Bilisten',
#  660: 'Cool Whip',
#  661: 'Realtor',
#  662: 'Granada',
#  663: 'Intermarche',
#  664: 'The Batman',
#  665: 'San Miguel',
#  666: 'Lego',
#  667: 'Mintad',
#  668: 'Great Wall',
#  669: 'Mavic',
#  670: 'Oops All Berries',
#  671: 'Premium',
#  672: 'Sugar Sprinkled Twinkles',
#  673: 'AVON',
#  674: 'Seasons 52',
#  675: 'SnackWells',
#  676: 'yanlaihong',
#  677: 'AERIAL7',
#  678: 'AC',
#  679: 'Esquires',
#  680: '24seven',
#  681: 'Carnation (brand)',
#  682: 'Vana Tallinn',
#  683: 'Kinnie',
#  684: 'Tetley',
#  685: 'Telepizza',
#  686: 'Sunstar',
#  687: 'VH',
#  688: 'coles',
#  689: 'BOSCH',
#  690: 'Neckermann',
#  691: 'La Perla',
#  692: 'Rice Krispies',
#  693: 'Savory',
#  694: 'Cabana',
#  695: "Uncle Joe's Mint Balls",
#  696: 'Sysline',
#  697: 'Connector',
#  698: 'Pokemon',
#  699: 'Emerica',
#  700: "Hardee's",
#  701: 'Radio Flyer',
#  702: 'TECO',
#  703: 'Toronto',
#  704: 'Amstrad',
#  705: 'JS',
#  706: 'Hoffmann',
#  707: 'Lagunitas',
#  708: 'Gel',
#  709: "Totino's",
#  710: 'Lanka',
#  711: 'General Electric',
#  712: 'Hancock',
#  713: 'Basil',
#  714: 'Costa Coffee',
#  715: 'Nido',
#  716: 'Estuary',
#  717: 'Hot Pockets',
#  718: 'Ipso',
#  719: 'Dawa',
#  720: 'Lane Furniture',
#  721: 'Polaroid',
#  722: 'Oronamin C',
#  723: 'Savage',
#  724: 'Mirc',
#  725: 'Dollar Tree',
#  726: 'Hitachi1',
#  727: 'Always',
#  728: 'Unicef',
#  729: 'La Laitiere',
#  730: 'High School Musical',
#  731: 'Cosi',
#  732: 'Peter Pan',
#  733: 'R&I',
#  734: 'Shaw',
#  735: 'Kraft Eating Right',
#  736: 'MultiGrain Cheerios',
#  737: 'Oat Crisp',
#  738: 'Valero',
#  739: 'La Escepcion',
#  740: 'Heaven_',
#  741: 'Singer',
#  742: 'SHINETIME',
#  743: 'Britannia',
#  744: 'Caltex',
#  745: 'Frosted Flakes',
#  746: 'DVS Shoes',
#  747: 'Paz',
#  748: 'Alpen Gold',
#  749: 'Molson Dry',
#  750: 'MICROPLANE',
#  751: 'Dyson',
#  752: 'Avion',
#  753: "Copeland's",
#  754: 'Aquafina',
#  755: 'Irn Bru Bar',
#  756: 'Cheaders',
#  757: 'Alpha-Bits',
#  758: 'Timotei',
#  759: 'Fruit of the Loom',
#  760: 'Usha',
#  761: 'Cello',
#  762: 'Harvest Moon',
#  763: 'Ted Drewes',
#  764: 'Klogs',
#  765: 'Tesco',
#  766: 'Wipro',
#  767: 'Georgia Boot',
#  768: 'Sampo',
#  769: 'Lane',
#  770: 'Boston Market',
#  771: 'Zamberlan',
#  772: 'Litespeed',
#  773: 'Blue Sky',
#  774: 'Maizena',
#  775: 'Jamba Juice',
#  776: 'Noodles & Company',
#  777: 'Prize',
#  778: 'Buick',
#  779: 'Victoria',
#  780: 'KAWASAKI',
#  781: 'Quality',
#  782: 'Tidy Cats',
#  783: 'Noble',
#  784: 'Motobecane',
#  785: 'Allegiant Air',
#  786: 'ConAgra Foods',
#  787: 'BMW',
#  788: 'Toy Machine',
#  789: 'CTS',
#  790: "Lyon's",
#  791: 'Benelli',
#  792: 'Freightliner',
#  793: 'Extra',
#  794: 'Koko Krunch',
#  795: 'Sea & Sea',
#  796: 'Impact',
#  797: 'Abici',
#  798: 'Isuzu',
#  799: 'SNOOPY',
#  800: 'BCP',
#  801: 'Alec Bradley',
#  802: 'Java',
#  803: 'aceh',
#  804: 'Amazon at Lab126',
#  805: 'Wonka Bars',
#  806: 'Che',
#  807: 'Waterman',
#  808: 'Andrea Electronics',
#  809: 'Frontier',
#  810: 'Lucky',
#  811: 'Orion',
#  812: 'Pearson',
#  813: 'KINGSTON',
#  814: 'Capri',
#  815: 'Walkers Shortbread',
#  816: 'Belvita',
#  817: 'Walch',
#  818: 'vatti',
#  819: 'Cosan',
#  820: 'Black Angus Steakhouse',
#  821: 'Twix',
#  822: 'niulanghan',
#  823: 'BLACKBERRY',
#  824: 'cestbon',
#  825: 'Lakefront',
#  826: 'Bold',
#  827: 'MG',
#  828: 'Astor',
#  829: 'Marshmallow',
#  830: 'Colinas',
#  831: "Terry's",
#  832: 'Rahr',
#  833: 'Norco',
#  834: 'Orbea',
#  835: 'AirTran Airways',
#  836: 'Beacon',
#  837: 'Twin Peaks',
#  838: 'Beko',
#  839: 'Ruger',
#  840: 'Olmeca',
#  841: 'Cheerios',
#  842: 'All-Bran',
#  843: "Arby's",
#  844: 'Project Eden',
#  845: 'Boulder',
#  846: 'BACCARAT',
#  847: 'Uno Chicago Grill',
#  848: 'Steyr',
#  849: 'Ross',
#  850: 'CHEF',
#  851: 'hp',
#  852: 'La Palina',
#  853: 'Conimex',
#  854: 'Coronaa',
#  855: 'Esso',
#  856: 'The Simpsons',
#  857: 'BaiDu',
#  858: 'Sure',
#  859: "Bird's Custard",
#  860: 'Quorum',
#  861: "Murphy's",
#  862: 'Bluegrass',
#  863: 'Daewoo',
#  864: 'Nintendo',
#  865: 'Kirkland Signature',
#  866: 'Harrison',
#  867: 'Gota',
#  868: 'Oki',
#  869: 'Diana',
#  870: 'Buitoni',
#  871: 'Kitkat',
#  872: 'Punch',
#  873: 'Solo',
#  874: 'Texas Instruments',
#  875: 'Sodastream',
#  876: 'Shell',
#  877: 'Extreme',
#  878: 'Best Western Hotels',
#  879: 'Orlen',
#  880: 'Ilford Photo',
#  881: 'Kins',
#  882: 'Capital',
#  883: 'Clement',
#  884: 'Bru',
#  885: 'Phillies',
#  886: 'Blue Hills',
#  887: 'Eukanuba',
#  888: 'Aspen Home',
#  889: 'CMC',
#  890: 'Mumtaz',
#  891: 'Paragon Pictures',
#  892: 'Vive',
#  893: 'Beneful',
#  894: "Shrek's",
#  895: 'Hot Wheels',
#  896: 'eMachines',
#  897: 'Creemore',
#  898: 'Cisco Systems',
#  899: 'Musashi',
#  900: 'Pathe',
#  901: 'Root Beer',
#  902: 'Black Horse',
#  903: 'Gambit',
#  904: 'Transformers',
#  905: 'Club Social',
#  906: 'Miko',
#  907: "Kwality Wall's",
#  908: 'Birmingham',
#  909: 'Golite',
#  910: 'MINI',
#  911: 'Nestea',
#  912: 'Subway',
#  913: 'Primos',
#  914: 'Sonic Drive-In',
#  915: 'Brut',
#  916: 'Cherry 7Up',
#  917: 'HTC',
#  918: 'Cracker Jack',
#  919: 'Sprecher',
#  920: 'Chicago',
#  921: 'Impulse',
#  922: 'Crazy Cow',
#  923: 'Lacto',
#  924: 'OKs',
#  925: 'Metro AG',
#  926: 'Ricore',
#  927: 'HaiNan Airlines',
#  928: 'Hyundai',
#  929: 'U.S. Traveler',
#  930: 'Kuota',
#  931: 'Colnago',
#  932: 'Kaiser',
#  933: "Cameron's",
#  934: 'Daewoo Electronics',
#  935: "Nobby's Nuts",
#  936: 'Google',
#  937: 'HEC',
#  938: 'Diplomaticos',
#  939: 'Indomie Mi goreng',
#  940: 'BTC',
#  941: 'Suchard',
#  942: 'Uway',
#  943: 'Nestle Drumstick',
#  944: 'Fujitsu',
#  945: 'Circus Fun',
#  946: 'Double Take',
#  947: 'Danish',
#  948: 'TAG Heuer',
#  949: 'Osram Sylvania',
#  950: 'Salewa',
#  951: 'Mojang',
#  952: 'Buxton',
#  953: 'Carling',
#  954: 'Ala',
#  955: 'Ssangyong',
#  956: 'Ducati',
#  957: 'Leica',
#  958: 'Double Chocolate Krave',
#  959: 'American Star Bicycle',
#  960: 'ANCAP',
#  961: 'Coffee-Mate',
#  962: "Sarson's",
#  963: 'Specialized',
#  964: 'El Jimador',
#  965: 'Sauza',
#  966: 'RedDragnfly',
#  967: 'BH',
#  968: 'Nestle NesQuik',
#  969: 'Tres',
#  970: 'Kah Tequila',
#  971: 'Porsche',
#  972: 'Traveler',
#  973: 'St',
#  974: 'Kross',
#  975: 'Sanyo',
#  976: 'Manhattan Portage',
#  977: 'Johnson & Johnson',
#  978: 'Kapsch',
#  979: 'Aqua Spring',
#  980: 'Frito-Lay',
#  981: 'Baker Skateboards',
#  982: 'Molson Export',
#  983: 'Hospitals',
#  984: 'Triscuit',
#  985: "Butterfinger BB's",
#  986: 'Padron',
#  987: 'Dolce & Gabbana',
#  988: 'Diesel',
#  989: 'Angry Orchard',
#  990: 'Asus',
#  991: 'Naleczowianka',
#  992: 'MarsInc',
#  993: 'AICO',
#  994: 'Mossberg',
#  995: 'PerkinElmer',
#  996: 'Boo Berry',
#  997: 'Yellow Cab Pizza Co',
#  998: 'Dubble Bubble',
#  999: 'Deer Park',
#  ...}
